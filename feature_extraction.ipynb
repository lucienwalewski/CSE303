# %% [markdown]
# ## Feature Extraction ##
# Given an episode number, this code extracts features from all the labeled interacting pairs of tracks in the episode (interacs_bool = False will gather all non-interacting pairs).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
episode_no = 14
interacs_bool = True
episode_str = f'episode{str(episode_no).zfill(2)}'
if not interacs_bool:
  full_episode_str = episode_str+ '_nointeracs'
else:
  full_episode_str = episode_str

# %% [markdown]
# ## Preparing the Model and Data##

# %%
FRAME_PATH = f'drive/MyDrive/Friends/frames/episode{str(episode_no).zfill(2)}.tar.gz' #change me
SHOTS_PATH = f'drive/MyDrive/Friends/shots/shots.tar.gz' #change me
TRACK_PATH = f'drive/MyDrive/Friends/tracks-features/Friends.pk' #change me
VIDEO_PATH = f'drive/MyDrive/Friends_Extra/episode{str(episode_no).zfill(2)}.mp4' #change me
MODEL_PATH = f'drive/MyDrive/friends_annotations/resnet-18-kinetics.pth'

# %%
! git clone https://github.com/kenshohara/video-classification-3d-cnn-pytorch classification
# Out:
# Cloning into 'classification'...
# remote: Enumerating objects: 121, done.
# remote: Total 121 (delta 0), reused 0 (delta 0), pack-reused 121
# Receiving objects: 100% (121/121), 158.63 KiB | 2.09 MiB/s, done.
# Resolving deltas: 100% (63/63), done.

# %%
! mkdir data
! tar xzf $SHOTS_PATH -C data
! tar xzf $FRAME_PATH -C classification
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %% [markdown]
# ## Loading Data ##

# %%
def load_shots():
  shots = {}
  i = 0
  with open(f'data/shots/season3/episode{str(episode_no).zfill(2)}_shots.txt', 'r') as f:
    for l in f:
      boundaries = l.split(' ')
      assert len(boundaries) == 2
      start, end = int(boundaries[0].strip()), int(boundaries[1].strip())
      shots[i]  = (start, end)
      i += 1
  return shots

# %%
def load_tracks():
  import pickle
  with open(TRACK_PATH, 'rb') as f:
    tracks = pickle.load(f)
  return tracks

# %%
def load_track_boundaries(tracks):
  
  track_boundaries = {}

  for i in tracks[episode_str]['GT']:
    for features in ['body', 'face']:
      if i in tracks[episode_str][features]:
        l = tracks[episode_str][features][i]
        start, end = l[0,0], l[-1,0]
        if end - start > 16:
          if i not in track_boundaries:
            track_boundaries[i] = (start, end)

  return track_boundaries

# %%
def load_tracks_to_shots(track_boundaries):
  tracks_to_shots = {}
  for i, (track_s, track_e) in track_boundaries.items():
    for s in shots:
      if shots[s][0] <= track_s <= track_e <= shots[s][1]:
        tracks_to_shots[i] = s 
  return tracks_to_shots

# %%
def load_interacc_annot(interacc_bool):
  % cd drive/MyDrive/friends_annotations
  from parse_csv_annotations import gather_annotations
  annotations = gather_annotations(episode_no)
  % cd -
  if interacc_bool:
    return annotations['full physical'] + annotations['partial physical'] + annotations['full non-physical'] + annotations['partial non-physical']
  return annotations['no interaction']

# %%
def load_interactions(interacc_annot, tracks_to_shots):
  interactions = []
  for interacc in interacc_annot:
    shot_id = interacc[1]
    person1, person2 = interacc[2], interacc[3]

    person1 = 'Jack Geller' if person1 == '"Jack Geller"' else person1
    person2 = 'Jack Geller' if person2 == '"Jack Geller"' else person2

    curr = []
    for i in tracks_to_shots:
      if tracks_to_shots[i] == shot_id:
        curr.append(i)

    for i in range(len(curr)):
      for j in range(len(curr)):
        if tracks[episode_str]['GT'][curr[i]] == person1:
          if tracks[episode_str]['GT'][curr[j]] == person2:
            if ((curr[i], curr[j])) not in interactions:
              interactions.append((curr[i], person1, curr[j], person2))
  interactions.sort()

  return interactions

# %%
def load_true_interaccs(tracks, interactions):
  true_interaccs = {}
  body_info = tracks[episode_str]['body']
  face_info = tracks[episode_str]['face']

  for track1, person1, track2, person2 in interactions:
    true_interaccs[(track1, person1, track2, person2)] = [[]]
    overall_frames = []

    info_1 = body_info if track1 in body_info else face_info
    info_2 = body_info if track2 in body_info else face_info
    
    for frames_i in info_1[track1][:,0]:
      if frames_i in info_2[track2][:,0]:
        overall_frames.append(frames_i)
    
    for i in range(len(overall_frames)):
      true_interaccs[(track1, person1, track2, person2)][-1].append(overall_frames[i])
      if i < len(overall_frames) - 1:
        if overall_frames[i] + 1 != overall_frames[i + 1]:
          true_interaccs[(track1, person1, track2, person2)].append([])
  return true_interaccs

# %%
def create_cropped_video(track_no, info, frames, FRAMES_PATH, VIDEO_PATH, video_name):
  if len(frames) < 2:
    return

  start, end = frames[0], frames[-1]

  TEMP_PATH = 'tmp'
  ! mkdir $TEMP_PATH
  
  count = 0
  for frame_bbx in info[track_no]:

    if start <= frame_bbx[0] <= end:
      pass
    else:
      continue

    frame_no = frame_bbx[0]
    x1, y1, x2, y2 = frame_bbx[1], frame_bbx[2], frame_bbx[3], frame_bbx[4]

    width = (x2 - x1)
    height = (y2 - y1)
  
    width_n = width * (1.15)**0.5
    height_n = height * (1.15)**0.5

    x_center = (x1 + x2) / 2
    y_center = (y1 + y2) / 2

    x1_n = x_center - (width_n / 2)
    x2_n = x_center + (width_n / 2)

    if x1_n < 0:
      width_n += 2 * x1_n
      x1_n = 0

    if x1_n + width_n > 1280:
      width_n -= x1_n + width_n - 1280

    y1_n = y_center - (height_n / 2) 
    y2_n = y_center + (height_n / 2)

    if y1_n < 0:
      height_n += 2 * y1_n
      y1_n = 0

    if y1_n + height_n > 720:
      height_n -= y1_n + height_n - 720

    crop_str = f'"crop={width_n}:{height_n}:{x1_n}:{y1_n}"'
    scale_str = "scale=112:112:force_original_aspect_ratio=decrease,pad=112:112:-1:-1:color=black"
    double_str= f"{crop_str},{scale_str}"

    img_fname = str(int(frame_no)).zfill(6) + ".jpg"
    in_img = os.path.join(FRAMES_PATH, img_fname)
    out_fno = str(int(count)).zfill(4) + ".jpg"
    out_img = os.path.join(TEMP_PATH, out_fno)

    ! ffmpeg -i $in_img -vf $double_str $out_img 

    count += 1

  out_video = VIDEO_PATH + video_name
  in_frames = TEMP_PATH + '/%4d.jpg'
  ! ffmpeg -f image2 -i $in_frames $out_video 

  ! rm -r $TEMP_PATH

# %%
shots = load_shots()

# %%
tracks = load_tracks()

# %%
track_boundaries = load_track_boundaries(tracks)
tracks_to_shots = load_tracks_to_shots(track_boundaries)
interacc_annot = load_interacc_annot(interacs_bool)
interactions = load_interactions(interacc_annot, tracks_to_shots)
true_interaccs = load_true_interaccs(tracks, interactions)
# Out:
# /content/drive/MyDrive/friends_annotations
# /content

# %% [markdown]
# ## Create Tracks Video ##

# %%
import os
% cd classification

body_info = tracks[episode_str]['body']
face_info = tracks[episode_str]['face']

! mkdir video

for (track_i, person_i, track_j, person_j) in true_interaccs:

  frames = true_interaccs[(track_i, person_i, track_j, person_j)]

  info_i = body_info if track_i in body_info else face_info
  info_j = body_info if track_j in body_info else face_info


  for k in range(len(frames)):
    
    track_path = f'track_{str(track_i).zfill(3)}_{str(track_j).zfill(3)}_{k}'

    track_str_i = f'{str(track_i).zfill(3)}_{str(track_j).zfill(3)}_{k}.mp4'
    track_str_j = f'{str(track_j).zfill(3)}_{str(track_i).zfill(3)}_{k}.mp4'

    frame_path = f'datasets/friends/frames/season3/{episode_str}'

    create_cropped_video(track_i, info_i, frames[k], frame_path, 'video', track_str_i)
    create_cropped_video(track_j, info_j, frames[k], frame_path, 'video', track_str_j)

% cd -
# Out:
# Streaming output truncated to the last 5000 lines.
# [swscaler @ 0x557010018000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x557010018000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0117.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 12544:12483 DAR 12544:12483], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.78x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030449.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 12761 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55f70242c000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55f70242c000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0118.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 6328:6327 DAR 6328:6327], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=6.03x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030450.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 12598 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55d5e3f48000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55d5e3f48000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0119.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 224:225 DAR 224:225], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.38x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030451.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 12806 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5564cdcd6000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x5564cdcd6000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0120.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 224:225 DAR 224:225], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.62x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030452.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 12661 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x564f21b94000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x564f21b94000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0121.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 2576:2565 DAR 2576:2565], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.54x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030453.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 12844 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55b1150e4000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55b1150e4000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0122.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 6496:6479 DAR 6496:6479], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.86x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030454.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 12608 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x558356c14000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x558356c14000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0123.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 3728:3751 DAR 3728:3751], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.62x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030455.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 12774 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55a5f6092000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55a5f6092000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0124.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 932:935 DAR 932:935], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.32x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030456.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 12674 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x562067cbe000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x562067cbe000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0125.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 936:935 DAR 936:935], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.36x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030457.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 12795 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55ff1eb2e000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55ff1eb2e000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0126.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 13216:13221 DAR 13216:13221], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.88x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030458.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 12785 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5607a05ec000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x5607a05ec000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0127.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 4424:4407 DAR 4424:4407], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed= 5.8x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'tmp/%4d.jpg':
#   Duration: 00:00:05.12, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 112x112 [SAR 6244:6205 DAR 6244:6205], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5621a102de00] using SAR=1601/1591
# [libx264 @ 0x5621a102de00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5621a102de00] profile High, level 1.0
# [libx264 @ 0x5621a102de00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'video536_535_0.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 6244:6205 DAR 6244:6205], q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  128 fps=0.0 q=-1.0 Lsize=      22kB time=00:00:05.00 bitrate=  36.6kbits/s speed=34.4x
# video:20kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 11.505633%
# [libx264 @ 0x5621a102de00] frame I:1     Avg QP:18.39  size:  1759
# [libx264 @ 0x5621a102de00] frame P:36    Avg QP:22.75  size:   347
# [libx264 @ 0x5621a102de00] frame B:91    Avg QP:19.49  size:    61
# [libx264 @ 0x5621a102de00] consecutive B-frames:  3.9%  1.6%  7.0% 87.5%
# [libx264 @ 0x5621a102de00] mb I  I16..4: 28.6% 57.1% 14.3%
# [libx264 @ 0x5621a102de00] mb P  I16..4:  0.5%  5.3%  0.3%  P16..4: 20.4% 23.6% 17.6%  0.0%  0.0%    skip:32.2%
# [libx264 @ 0x5621a102de00] mb B  I16..4:  1.2%  0.4%  0.0%  B16..8: 37.7%  6.6%  0.7%  direct: 0.6%  skip:52.7%  L0:45.3% L1:47.3% BI: 7.4%
# [libx264 @ 0x5621a102de00] 8x8 transform intra:60.2% inter:39.6%
# [libx264 @ 0x5621a102de00] coded y,uvDC,uvAC intra: 26.9% 29.9% 18.2% inter: 7.2% 9.0% 1.5%
# [libx264 @ 0x5621a102de00] i16 v,h,dc,p: 96%  0%  4%  0%
# [libx264 @ 0x5621a102de00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11%  7% 69%  2%  1%  2%  1%  4%  4%
# [libx264 @ 0x5621a102de00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28%  3%  8% 10% 12% 12%  9%  9%  8%
# [libx264 @ 0x5621a102de00] i8c dc,h,v,p: 68%  3% 25%  3%
# [libx264 @ 0x5621a102de00] Weighted P-Frames: Y:2.8% UV:0.0%
# [libx264 @ 0x5621a102de00] ref P L0: 60.7% 16.2% 16.0%  6.8%  0.3%
# [libx264 @ 0x5621a102de00] ref B L0: 79.4% 15.8%  4.7%
# [libx264 @ 0x5621a102de00] ref B L1: 95.0%  5.0%
# [libx264 @ 0x5621a102de00] kb/s:30.96
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030331.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 13298 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x563380312000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x563380312000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0000.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 29568:29593 DAR 29568:29593], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.1 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.88x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030332.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 13353 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55baccc98000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55baccc98000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0001.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 29568:29593 DAR 29568:29593], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.99x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030333.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 13490 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55b7c87c0000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55b7c87c0000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0002.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 29568:29593 DAR 29568:29593], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.98x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030334.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 13601 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5589c6010000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x5589c6010000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0003.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 29568:29593 DAR 29568:29593], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.96x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030335.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 13808 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55d82cfc6000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55d82cfc6000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0004.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 29680:29593 DAR 29680:29593], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.2 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.96x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/030336.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 13551 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x56343f86a000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x56343f86a000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0005.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
# ...
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/004984.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 25080 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5648ce8c8000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x5648ce8c8000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0019.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 8848:8815 DAR 8848:8815], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.7 Lsize=N/A time=00:00:00.04 bitrate=N/A speed= 5.2x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/004985.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 25688 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55946f562000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55946f562000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0020.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 1904:1899 DAR 1904:1899], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.8 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.46x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/004986.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 25720 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55d8a273a000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55d8a273a000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0021.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 5264:5293 DAR 5264:5293], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.7 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.09x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/004987.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 25649 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x563ca8b9c000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x563ca8b9c000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0022.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 1096:1089 DAR 1096:1089], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.7 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.31x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/004988.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 26088 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55c46d360000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55c46d360000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0023.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 3920:3939 DAR 3920:3939], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.7 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=5.03x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'datasets/friends/frames/season3/episode13/004989.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 26719 kb/s
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x55915d7de000] deprecated pixel format used, make sure you did set range correctly
# [swscaler @ 0x55915d7de000] Warning: data is not aligned! This can lead to a speed loss
# Output #0, image2, to 'tmp/0024.jpg':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: mjpeg, yuvj420p(pc), 112x112 [SAR 1316:1313 DAR 1316:1313], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    1 fps=0.0 q=2.7 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=4.99x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %% [markdown]
# ## Extracting Feature Vectors ##
# Finally, we can use 3D ResNet to extract the feature vector.

# %%
! cp drive/MyDrive/friends_annotations/resnet-18-kinetics.pth classification/models # change to location of model

# %%
! mkdir classification/video
import os

for f in os.listdir('classification'):
  if f[:5] == 'video' and f != 'video':
    file = f'classification/{f}'
    # !mv $file classification/video
# Out:
# mkdir: cannot create directory ‘classification/video’: No such file or directory
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-4dce361d9f63> in <module>()
#       2 import os
#       3
# ----> 4 for f in os.listdir('classification'):
#       5   if f[:5] == 'video' and f != 'video':
#       6     file = f'classification/{f}'
#
# FileNotFoundError: [Errno 2] No such file or directory: 'classification'

# %%
!

# %%
# add opt.model_depth = 18 in line 17 in classification/main.py
import os
% cd classification
! mkdir outputs
video_path = 'video'
for f in os.listdir(video_path):
  with open('input', 'w') as file:
    file.write(f)
    file.write('\n')
  output_loc = f'outputs/output_{f}.json'
  ! touch $output_loc
  ! python main.py --input input --video_root $video_path --output $output_loc --model ./models/resnet-18-kinetics.pth --mode feature
% cd -
# Out:
# Streaming output truncated to the last 5000 lines.
#   Duration: 00:00:10.20, start: 0.000000, bitrate: 75 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 1974:1969 DAR 1974:1969], 72 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 1974:1969 DAR 1974:1969], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  255 fps=0.0 q=10.5 Lsize=N/A time=00:00:10.20 bitrate=N/A speed=94.2x
# video:326kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video418_420_1.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video418_420_1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:08.04, start: 0.000000, bitrate: 81 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 1815:1813 DAR 1815:1813], 78 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 1815:1813 DAR 1815:1813], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  201 fps=0.0 q=11.7 Lsize=N/A time=00:00:08.04 bitrate=N/A speed= 101x
# video:265kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video354_355_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video354_355_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:00.84, start: 0.000000, bitrate: 106 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 1889:1884 DAR 1889:1884], 95 kb/s, SAR 25312:25245 DAR 25312:25245, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 25312:25245 DAR 25312:25245], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   21 fps=0.0 q=6.1 Lsize=N/A time=00:00:00.84 bitrate=N/A speed=75.1x
# video:50kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video389_383_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video389_383_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:00.96, start: 0.000000, bitrate: 149 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 2576:2565 DAR 2576:2565], 139 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 2576:2565 DAR 2576:2565], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   24 fps=0.0 q=5.6 Lsize=N/A time=00:00:00.96 bitrate=N/A speed=74.3x
# video:51kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video508_506_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video508_506_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:03.16, start: 0.000000, bitrate: 78 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 1128:1127 DAR 1128:1127], 73 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 1128:1127 DAR 1128:1127], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   79 fps=0.0 q=11.4 Lsize=N/A time=00:00:03.16 bitrate=N/A speed=88.6x
# video:131kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video309_310_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video309_310_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:00.76, start: 0.000000, bitrate: 54 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 3976:3995 DAR 3976:3995], 43 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 3976:3995 DAR 3976:3995], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   19 fps=0.0 q=2.6 Lsize=N/A time=00:00:00.76 bitrate=N/A speed=41.4x
# video:35kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video228_227_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video228_227_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:08.00, start: 0.000000, bitrate: 84 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 4035:4004 DAR 4035:4004], 81 kb/s, SAR 4816:4779 DAR 4816:4779, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 4816:4779 DAR 4816:4779], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  200 fps=0.0 q=12.5 Lsize=N/A time=00:00:08.00 bitrate=N/A speed=75.7x
# video:275kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video145_151_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video145_151_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:03.20, start: 0.000000, bitrate: 77 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 245:243 DAR 245:243], 73 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 245:243 DAR 245:243], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   80 fps=0.0 q=5.3 Lsize=N/A time=00:00:03.20 bitrate=N/A speed=89.1x
# video:122kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video483_482_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video483_482_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:05.56, start: 0.000000, bitrate: 87 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 4009:4021 DAR 4009:4021], 84 kb/s, SAR 9688:9717 DAR 9688:9717, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 9688:9717 DAR 9688:9717], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  139 fps=0.0 q=14.7 Lsize=N/A time=00:00:05.56 bitrate=N/A speed=94.1x
# video:208kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video556_557_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video556_557_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:04.64, start: 0.000000, bitrate: 89 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 196:195 DAR 196:195], 85 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 196:195 DAR 196:195], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  116 fps=0.0 q=12.7 Lsize=N/A time=00:00:04.64 bitrate=N/A speed=94.4x
# video:182kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video240_239_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video240_239_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:00.76, start: 0.000000, bitrate: 91 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 645:644 DAR 645:644], 80 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 645:644 DAR 645:644], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   19 fps=0.0 q=3.2 Lsize=N/A time=00:00:00.76 bitrate=N/A speed=76.7x
# video:39kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video198_202_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video198_202_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:06.64, start: 0.000000, bitrate: 51 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 204:205 DAR 204:205], 47 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 204:205 DAR 204:205], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  166 fps=0.0 q=9.5 Lsize=N/A time=00:00:06.64 bitrate=N/A speed=79.6x
# video:245kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video512_513_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video512_513_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:02.80, start: 0.000000, bitrate: 75 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 1127:1130 DAR 1127:1130], 71 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 1127:1130 DAR 1127:1130], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   70 fps=0.0 q=11.7 Lsize=N/A time=00:00:02.80 bitrate=N/A speed=93.8x
# video:120kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video201_202_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video201_202_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:05.24, start: 0.000000, bitrate: 86 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 1455:1456 DAR 1455:1456], 82 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 1455:1456 DAR 1455:1456], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  131 fps=0.0 q=15.4 Lsize=N/A time=00:00:05.24 bitrate=N/A speed=93.6x
# video:195kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ...
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video381_391_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:00.12, start: 0.000000, bitrate: 236 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 280:279 DAR 280:279], 176 kb/s, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 280:279 DAR 280:279], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=    3 fps=0.0 q=1.6 Lsize=N/A time=00:00:00.12 bitrate=N/A speed=35.7x
# video:7kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Traceback (most recent call last):
#   File "main.py", line 58, in <module>
#     result = classify_video('tmp', input_file, class_names, model, opt)
#   File "/content/classification/classify.py", line 31, in classify_video
#     video_outputs = torch.cat(video_outputs)
# NotImplementedError: There were no tensor arguments to this function (e.g., you passed an empty list of Tensors), but no fallback function is registered for schema aten::_cat.  This usually means that this function requires a non-empty list of Tensors, or that you (the operator writer) forgot to register a fallback function.  Available functions are [CPU, CUDA, QuantizedCPU, BackendSelect, Python, Named, Conjugate, Negative, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradXLA, AutogradLazy, AutogradXPU, AutogradMLC, AutogradHPU, AutogradNestedTensor, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, Tracer, UNKNOWN_TENSOR_TYPE_ID, Autocast, Batched, VmapMode].
#
# CPU: registered at aten/src/ATen/RegisterCPU.cpp:18433 [kernel]
# CUDA: registered at aten/src/ATen/RegisterCUDA.cpp:26496 [kernel]
# QuantizedCPU: registered at aten/src/ATen/RegisterQuantizedCPU.cpp:1068 [kernel]
# BackendSelect: fallthrough registered at ../aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at ../aten/src/ATen/core/PythonFallbackKernel.cpp:47 [backend fallback]
# Named: registered at ../aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at ../aten/src/ATen/ConjugateFallback.cpp:18 [backend fallback]
# Negative: registered at ../aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ADInplaceOrView: fallthrough registered at ../aten/src/ATen/core/VariableFallbackKernel.cpp:64 [backend fallback]
# AutogradOther: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradCPU: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradCUDA: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradXLA: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradLazy: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradXPU: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradMLC: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradHPU: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradNestedTensor: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradPrivateUse1: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradPrivateUse2: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradPrivateUse3: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# Tracer: registered at ../torch/csrc/autograd/generated/TraceType_3.cpp:11560 [kernel]
# UNKNOWN_TENSOR_TYPE_ID: fallthrough registered at ../aten/src/ATen/autocast_mode.cpp:466 [backend fallback]
# Autocast: fallthrough registered at ../aten/src/ATen/autocast_mode.cpp:305 [backend fallback]
# Batched: registered at ../aten/src/ATen/BatchingRegistrations.cpp:1016 [backend fallback]
# VmapMode: fallthrough registered at ../aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
#
# loading model ./models/resnet-18-kinetics.pth
# video/video545_544_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video545_544_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:04.08, start: 0.000000, bitrate: 68 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 4096:4095 DAR 4096:4095], 64 kb/s, SAR 5796:5795 DAR 5796:5795, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 5796:5795 DAR 5796:5795], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=  102 fps=0.0 q=12.6 Lsize=N/A time=00:00:04.08 bitrate=N/A speed=71.6x
# video:159kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /content/classification/classify.py:25: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   inputs = Variable(inputs, volatile=True)
# loading model ./models/resnet-18-kinetics.pth
# video/video419_421_0.mp4
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video/video419_421_0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:00.52, start: 0.000000, bitrate: 70 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc), 112x112 [SAR 2237:2231 DAR 2237:2231], 55 kb/s, SAR 7084:7065 DAR 7084:7065, 25 fps, 25 tbr, 12800 tbn, 50 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'tmp/image_%05d.jpg':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 112x112 [SAR 7084:7065 DAR 7084:7065], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame=   13 fps=0.0 q=4.8 Lsize=N/A time=00:00:00.52 bitrate=N/A speed=70.6x
# video:38kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Traceback (most recent call last):
#   File "main.py", line 58, in <module>
#     result = classify_video('tmp', input_file, class_names, model, opt)
#   File "/content/classification/classify.py", line 31, in classify_video
#     video_outputs = torch.cat(video_outputs)
# NotImplementedError: There were no tensor arguments to this function (e.g., you passed an empty list of Tensors), but no fallback function is registered for schema aten::_cat.  This usually means that this function requires a non-empty list of Tensors, or that you (the operator writer) forgot to register a fallback function.  Available functions are [CPU, CUDA, QuantizedCPU, BackendSelect, Python, Named, Conjugate, Negative, ADInplaceOrView, AutogradOther, AutogradCPU, AutogradCUDA, AutogradXLA, AutogradLazy, AutogradXPU, AutogradMLC, AutogradHPU, AutogradNestedTensor, AutogradPrivateUse1, AutogradPrivateUse2, AutogradPrivateUse3, Tracer, UNKNOWN_TENSOR_TYPE_ID, Autocast, Batched, VmapMode].
#
# CPU: registered at aten/src/ATen/RegisterCPU.cpp:18433 [kernel]
# CUDA: registered at aten/src/ATen/RegisterCUDA.cpp:26496 [kernel]
# QuantizedCPU: registered at aten/src/ATen/RegisterQuantizedCPU.cpp:1068 [kernel]
# BackendSelect: fallthrough registered at ../aten/src/ATen/core/BackendSelectFallbackKernel.cpp:3 [backend fallback]
# Python: registered at ../aten/src/ATen/core/PythonFallbackKernel.cpp:47 [backend fallback]
# Named: registered at ../aten/src/ATen/core/NamedRegistrations.cpp:7 [backend fallback]
# Conjugate: registered at ../aten/src/ATen/ConjugateFallback.cpp:18 [backend fallback]
# Negative: registered at ../aten/src/ATen/native/NegateFallback.cpp:18 [backend fallback]
# ADInplaceOrView: fallthrough registered at ../aten/src/ATen/core/VariableFallbackKernel.cpp:64 [backend fallback]
# AutogradOther: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradCPU: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradCUDA: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradXLA: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradLazy: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradXPU: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradMLC: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradHPU: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradNestedTensor: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradPrivateUse1: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradPrivateUse2: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# AutogradPrivateUse3: registered at ../torch/csrc/autograd/generated/VariableType_3.cpp:10141 [autograd kernel]
# Tracer: registered at ../torch/csrc/autograd/generated/TraceType_3.cpp:11560 [kernel]
# UNKNOWN_TENSOR_TYPE_ID: fallthrough registered at ../aten/src/ATen/autocast_mode.cpp:466 [backend fallback]
# Autocast: fallthrough registered at ../aten/src/ATen/autocast_mode.cpp:305 [backend fallback]
# Batched: registered at ../aten/src/ATen/BatchingRegistrations.cpp:1016 [backend fallback]
# VmapMode: fallthrough registered at ../aten/src/ATen/VmapModeRegistrations.cpp:33 [backend fallback]
#
# /content

# %%
import json
import os

final_dicts = []

for current_file in sorted(os.listdir('drive/MyDrive/friends_annotations/outputs_final')):

  curr_episode = current_file[:9]

  loc = f'drive/MyDrive/friends_annotations/outputs_final/{current_file}'
  ! unzip -qq $loc

  outputs_path = 'classification/outputs/'
  for outputs in os.listdir(outputs_path):
    if os.path.getsize(outputs_path + outputs) == 0:
      continue
    values = outputs[12:-9].split('_')
    track1 = int(values[0])
    track2 = int(values[1])
    version = int(values[2])


    person1 = tracks[curr_episode]['GT'][track1]
    person2 = tracks[curr_episode]['GT'][track2]
    with open(outputs_path + outputs) as f:
      js_obj = json.load(f)
      for i in js_obj[0]['clips']:
        curr_dict = {'track1' : track1,
                    'track2' : track2,
                    'person1' : person1,
                    'person2' : person2,
                    'version' : version,
                    'episode' : curr_episode,
                    'segment': i['segment'],
                    'features': i['features'],
                    'video' : js_obj[0]['video']}
        final_dicts.append(curr_dict)
      
  ! rm -r classification
